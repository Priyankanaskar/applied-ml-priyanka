# %%
import pandas as pd
howell_full = pd.read_csv("Howell.csv", sep=";")

# %%
howell_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sex,age,weight,height  783 non-null    object
# dtypes: object(1)
# memory usage: 6.2+ KB

# %%
print(howell_full.head(n=10))
# Out:
#      sex,age,weight,height
# 0    male,63.28,47.6,160.7
# 1     male,64.5,47.8,151.8
# 2    female,60.28,34.1,140
# 3   female,61.5,36.5,139.7
# 4  female,65.28,31.9,136.5
# 5   female,66.5,32.9,141.6
# 6      male,40.19,53,156.8
# 7    female,50.29,42,145.4
# 8  female,51.33,41.3,145.4
# 9       male,35.5,63,163.8

# %%
print(howell_full.describe())
# Out:
#          sex,age,weight,height
# count                      783
# unique                     779
# top     female,7.16,16.9,118.1
# freq                         3

# %%
print(howell_full.dtypes)
# Out:
# sex,age,weight,height    object
# dtype: object

# %%
howell_full = howell_full.apply(pd.to_numeric, errors='coerce')

# %%
howell_full.corr()
# Out:
#                        sex,age,weight,height
# sex,age,weight,height                    NaN

# %%
from pandas.plotting import scatter_matrix

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
print(howell_full.columns)
# Out:
# Index(['sex,age,weight,height'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = howell_full.corr()

sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.show()
# Out:
# c:\Users\priya\anaconda3\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# c:\Users\priya\anaconda3\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
import pandas as pd

file_path = "Howell.csv"  # Update this if needed
howell_full = pd.read_csv(file_path, sep=";")

print(howell_full.head())  # Check if 'height' and 'weight' exist
print(howell_full.columns)  # Verify correct column names
# Out:
#      sex,age,weight,height
# 0    male,63.28,47.6,160.7
# 1     male,64.5,47.8,151.8
# 2    female,60.28,34.1,140
# 3   female,61.5,36.5,139.7
# 4  female,65.28,31.9,136.5
# Index(['sex,age,weight,height'], dtype='object')

# %%
howell_full = pd.read_csv(file_path, sep=",", header=0)

# %%
import pandas as pd

file_path = "Howell.csv"  # Update the file path if needed
howell_full = pd.read_csv(file_path, sep=None, engine="python")

print(howell_full.head())  # Check if columns are correctly split
# Out:
#       sex    age  weight  height
# 0    male  63.28    47.6   160.7
# 1    male  64.50    47.8   151.8
# 2  female  60.28    34.1   140.0
# 3  female  61.50    36.5   139.7
# 4  female  65.28    31.9   136.5

# %%
howell_full = pd.read_csv(file_path, sep=",", header=0)

# %%
print(howell_full.columns)
# Out:
# Index(['sex', 'age', 'weight', 'height'], dtype='object')

# %%
howell_full.columns = ['sex', 'age', 'weight', 'height']
print(howell_full.head())  # Confirm the fix
# Out:
#       sex    age  weight  height
# 0    male  63.28    47.6   160.7
# 1    male  64.50    47.8   151.8
# 2  female  60.28    34.1   140.0
# 3  female  61.50    36.5   139.7
# 4  female  65.28    31.9   136.5

# %%
import matplotlib.pyplot as plt

height = howell_full['height']
weight = howell_full['weight']

plt.scatter(height, weight, color='blue', alpha=0.5)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Height vs. Weight Scatter Plot')

plt.show()

# %%
correlation_matrix = howell_full.select_dtypes(include=['number']).corr()
print(correlation_matrix)
# Out:
#              age    weight    height
# age     1.000000  0.687432  0.689238
# weight  0.687432  1.000000  0.937311
# height  0.689238  0.937311  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Drop non-numeric columns
numeric_data = howell_full.select_dtypes(include=['number'])

# Create correlation matrix
correlation_matrix = numeric_data.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
howell_full['new'] = howell_full['male'] + howell_full['age']
howell_full.drop(axis='columns', labels='new', inplace=True)
height_median = howell_full['height'].median()
weight_average = howell_full['weight'].mean()
howell_full['height'].fillna(height_median, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\priya\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'male'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 howell_full['new'] = howell_full['male'] + howell_full['age']
# ...

# %%
from pandas.plotting import scatter_matrix

attributes = ['height', 'weight', 'age']
scatter_matrix(howell_full[attributes]
# Out:
#   Cell In[77], line 4
#     scatter_matrix(howell_full[attributes]
#                                           ^
# SyntaxError: incomplete input
